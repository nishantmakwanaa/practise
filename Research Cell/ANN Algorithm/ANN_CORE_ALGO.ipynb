# %%
# Import Libraries
import tensorflow as tf
from keras import layers, models
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Load Dataset (Example : MNIST)
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
# Preprocess Data
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
# Build ANN model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Input layer
    layers.Dense(128, activation='relu'),  # Hidden Layer 1
    layers.Dense(64, activation='relu'),   # Hidden Layer 2
    layers.Dense(10, activation='softmax') # Output Layer
])

# %%
# Compile The Model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Train The Model
history = model.fit(
    train_images, train_labels,
    epochs=10,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8623 - loss: 0.4737 - val_accuracy: 0.9587 - val_loss: 0.1356
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9650 - loss: 0.1171 - val_accuracy: 0.9681 - val_loss: 0.1069
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9773 - loss: 0.0768 - val_accuracy: 0.9724 - val_loss: 0.0912
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9832 - loss: 0.0552 - val_accuracy: 0.9728 - val_loss: 0.0951
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9869 - loss: 0.0426 - val_accuracy: 0.9730 - val_loss: 0.0968
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9891 - loss: 0.0351 - val_accuracy: 0.9732 - val_loss: 0.0968
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9919 - loss: 0.0251 - val_accuracy: 0.9754 - val_loss: 0.0971
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9932 - loss: 0.0221 - val_accuracy: 0.9754 - val_loss: 0.1011
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9931 - loss: 0.0196 - val_accuracy: 0.9754 - val_loss: 0.1077
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9948 - loss: 0.0160 - val_accuracy: 0.9742 - val_loss: 0.1178

# %%
# Evaluate  Performance
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test Accuracy (Core Model) : {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - accuracy: 0.9729 - loss: 0.1038
# Test Accuracy (Core Model) : 0.9765

# %%
# Plot Training History
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.legend()
plt.show()
